# %% [markdown]
# # Laboratory 9 instruction part 2 - MLflow
#
# In machine learning development, one of the most challenging aspects is maintaining reproducibility. This issue is particularly relevant to the experimental phase, when a lot of small, but influential code changes are constantly introduced.
#
# After extensive experimentation with different model architectures, hyperparameters, and preprocessing techniques, researchers often find themselves unable to recreate their best-performing models because critical configuration details were not properly recorded.

# %% [markdown]
# ## MLflow
#
# [MLflow is an open-source platform](https://mlflow.org/) that addresses this challenge by providing systematic experiment tracking throughout the machine learning lifecycle. It automatically captures configurations, metrics, and artifacts from each model training run, transforming ad-hoc model development into a structured, reproducible process. In this notebook, we will learn how to use MLflow to properly track experiments for both traditional machine learning and deep learning workflows.

# %% [markdown]
# ### Learning objectives
#
# 1. **Implement automated experiment tracking** using MLflow autologging capabilities with scikit-learn, enabling automatic capture of model parameters and metrics without writing additional tracking code.
#
# 2. **Configure manual logging strategies** for PyTorch experiments, implementing custom tracking for metrics, parameters, and artifacts throughout the training process.
#
# 3. **Analyze and compare experimental results** using MLflow tracking UI and programmatic APIs to identify optimal model configurations and understand performance patterns.

# %% [markdown]
# ### Laboratory plan
#
# 1. **MLflow tracking server** configuration and deployment for experiment management
# 2. **Automatic logging mechanisms** for scikit-learn experiments
# 3. **Manual logging implementation** for PyTorch deep learning workflows
# 4. **Hyperparameter optimization exercise** - systematic hyperparameter exploration
# 5. **Best practices** for experiment organization, versioning, and cross-team reproducibility

# %% [markdown]
# ## 1. MLflow Tracking server configuration

# %% [markdown]
# [MLflow Tracking](https://mlflow.org/docs/latest/tracking/) is the main component of MLflow, responsible for capturing, storing, and presenting metrics, logs, and other tracking data. MLflow is based on a client-server architecture, where the central MLflow server can serve potentially whole teams of data scientists. You can also simply run it as a local server from the commandline, as we will now.

# %% [markdown]
# 1. Create a directory for MLflow artifacts storage:
# ```bash
# mkdir mlflow-artifacts
# ```
#
# 2. Start the MLflow tracking server:
# ```bash
# mlflow server \
#   --backend-store-uri sqlite:///mlflow.db \
#   --default-artifact-root ./mlflow-artifacts \
#   --host 0.0.0.0 \
#   --port 5000
# ```
# Important: Keep this terminal window open. The MLflow server will continue running and be accessible at http://localhost:5000

# %% [markdown]
# To verify if the server runs properly, let's connect to git:

# %%
import mlflow
import mlflow.sklearn

import warnings

warnings.filterwarnings("ignore")

mlflow.set_tracking_uri("http://localhost:5000")
print(f"Connected to MLflow at: {mlflow.get_tracking_uri()}")
# Out:
# Connected to MLflow at: http://localhost:5000

# %% [markdown]
# Setup complete! You now have the MLflow server running as a separate process, and `mlflow` library in this Jupyter Notebook is connected to it. Just note that we had to use the proper host and port - if you want to connect to a remote server, modify the tracking URI appropriately.

# %% [markdown]
# ## 2. Automatic logging with scikit-learn

# %% [markdown]
# ### 2.1 Dataset preparation
#
# In this section, we'll use the Ames Housing dataset to demonstrate MLflow's autologging capabilities with scikit-learn. Since we have already prepared the 2006-2008 data using DVC, we can use our preprocessed dataset here. As we have temporal data, the best way to evaluate our model is time (chronological) split, where the newest data is used for testing. We will assume that we have the data for years 2006 and 2007, and evaluate using data from 2008.

# %%
import numpy as np
import pandas as pd

from feature_engine.encoding import RareLabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# %%
df = pd.read_parquet("data/ames_data_2006_2008.parquet")

df = df.sort_values(by=["YrSold"])

df_train = df[df["YrSold"] < 2008]
df_test = df[df["YrSold"] == 2008]

y_train = df_train.pop("SalePrice")
y_test = df_test.pop("SalePrice")

categorical_features = df_train.select_dtypes(include="object").columns
numerical_features = df_train.select_dtypes(exclude="object").columns

# %%
median_imputer = SimpleImputer(strategy="median")
min_max_scaler = MinMaxScaler()
rare_encoder = RareLabelEncoder(tol=0.01, n_categories=0)
one_hot_encoder = OneHotEncoder(
    drop="first", sparse_output=False, handle_unknown="ignore"
)

num_pipeline = Pipeline(
    [("median_imputer", median_imputer), ("min_max_scaler", min_max_scaler)]
)

cat_pipeline = Pipeline(
    [("rare_encoder", rare_encoder), ("one_hot_encoder", one_hot_encoder)]
)

column_transformer = ColumnTransformer(
    [
        ("num_pipeline", num_pipeline, numerical_features),
        ("cat_pipeline", cat_pipeline, categorical_features),
    ],
    verbose_feature_names_out=False,
)
column_transformer.fit(df_train)

X_train = column_transformer.transform(df_train)
X_test = column_transformer.transform(df_test)

# %%
print(f"Training samples: {X_train.shape[0]}")
print(f"Test samples: {X_test.shape[0]}")
print(f"Number of features: {X_train.shape[1]}")
# Out:
# Training samples: 1312
# Test samples: 621
# Number of features: 181

# %% [markdown]
# ### 2.2 Training with MLflow autologging

# %% [markdown]
# Autologging is a powerful built-in capability of MLflow, enabling fully automated and near-zero code integration of MLflow with many popular frameworks. In particular, it works really well with scikit-learn, thanks to its highly unified API. Let's try this out - we will enable autologging, and then train a buch of different models.

# %%
mlflow.sklearn.autolog(
    log_input_examples=True, log_model_signatures=True, log_models=False, silent=False
)

mlflow.set_experiment("ames-housing-autolog")
# Out:
# 2025/06/07 14:08:41 WARNING mlflow.utils.autologging_utils: MLflow sklearn autologging is known to be compatible with 0.24.1 <= scikit-learn <= 1.6.1, but the installed version is 1.7.0. If you encounter errors during autologging, try upgrading / downgrading scikit-learn to a compatible version, or try upgrading MLflow.
# 2025/06/07 14:08:45 INFO mlflow.tracking.fluent: Experiment with name 'ames-housing-autolog' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/home/pawel/sandbox/studia_ai/id/lab06/mlflow-artifacts/1', creation_time=1749298125417, experiment_id='1', last_update_time=1749298125417, lifecycle_stage='active', name='ames-housing-autolog', tags={}>

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor


models = [
    ("Ridge Regression", Ridge()),
    ("Decision Tree", DecisionTreeRegressor(max_depth=10, random_state=42)),
    ("K-Nearest Neighbors", KNeighborsRegressor(n_neighbors=10)),
    ("Random Forest", RandomForestRegressor(n_estimators=100, random_state=42)),
    ("Gradient Boosting", GradientBoostingRegressor(n_estimators=100, random_state=42)),
]

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score


def fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test):
    results = {}

    for model_name, model in models:
        # start MLflow run - a unit grouping logs from different model runs
        # everything within this context manager will get logged as a run
        with mlflow.start_run(run_name=model_name):
            model.fit(X_train, y_train)

            y_pred = model.predict(X_test)

            rmse = root_mean_squared_error(y_test, y_pred)
            mae = mean_absolute_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)

            cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring="r2")
            cv_mean = cv_scores.mean()
            cv_std = cv_scores.std()
            
            # log additional custom metrics, in addition to autologging
            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            results[model_name] = {
                "rmse": rmse,
                "mae": mae,
                "r2": r2,
                "cv_r2_mean": cv_mean,
            }

            print(f"\n{model_name}:")
            print(f"  RMSE: {rmse:.2f}")
            print(f"  MAE: {mae:.2f}")
            print(f"  R^2: {r2:.3f}")
            print(f"  CV R^2 (mean ± std): {cv_mean:.3f} ± {cv_std:.3f}")

# %%
fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test)
# Out:
# 2025/06/07 14:08:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:08:52 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:08:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:08:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:08:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:08:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:08:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:08:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Ridge Regression:
#   RMSE: 23450.39
#   MAE: 16430.79
#   R^2: 0.904
#   CV R^2 (mean ± std): 0.880 ± 0.037
# 🏃 View run Ridge Regression at: http://localhost:5000/#/experiments/1/runs/4488f078d29045c6af66a84fafa1f7da
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/06/07 14:08:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:08:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:08:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:08:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:08:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:08:54 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Decision Tree:
#   RMSE: 36860.51
#   MAE: 23270.66
#   R^2: 0.762
#   CV R^2 (mean ± std): 0.726 ± 0.080
# 🏃 View run Decision Tree at: http://localhost:5000/#/experiments/1/runs/7f2ed2784664428d8311d82d4af90e23
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/06/07 14:08:54 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:08:54 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:08:54 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:08:54 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:08:54 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# K-Nearest Neighbors:
#   RMSE: 38325.08
#   MAE: 26034.48
#   R^2: 0.743
#   CV R^2 (mean ± std): 0.656 ± 0.050
# 🏃 View run K-Nearest Neighbors at: http://localhost:5000/#/experiments/1/runs/92e58a3a074748b79fceb403a3eed63a
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/06/07 14:08:57 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:08:59 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:09:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:09:03 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:09:05 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:09:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Random Forest:
#   RMSE: 25896.23
#   MAE: 15509.71
#   R^2: 0.883
#   CV R^2 (mean ± std): 0.870 ± 0.043
# 🏃 View run Random Forest at: http://localhost:5000/#/experiments/1/runs/8dd2a5096dfe4edf9ad2e14a2249015f
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2025/06/07 14:09:08 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:09:08 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:09:09 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:09:10 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/06/07 14:09:11 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Gradient Boosting:
#   RMSE: 21572.13
#   MAE: 13809.38
#   R^2: 0.919
#   CV R^2 (mean ± std): 0.898 ± 0.031
# 🏃 View run Gradient Boosting at: http://localhost:5000/#/experiments/1/runs/9925616361164b7caf2b0c2587b1e56e
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %% [markdown]
# Open the MLflow dashboard at http://localhost:5000/ and go to the Experiments tab. On the left, you have the experiment name, and when you select it, the list of all experiments will show up. Click through the interface and familiarize yourself with the most important elements:
#
# 1. What columns can be selected
# 2. Pick a particular run and check what values are logged automatically
# 3. Select columns to compare a given metric between runs, e.g. MAE
# 4. Sort algorithms by the selected metric to pick the best one

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# We have trained 5 different models. The results of all of them can now be compared in MLflow. Since we obtained quite satisfactory results, our imaginary client would like to be sure that we do our best and wants us to compare many more combinations.
#
# Your task is to run 5 more experiments with different parameters and models from scikit-learn. You can use any [supervised learning methods from scikit-learn](https://scikit-learn.org/stable/supervised_learning.html). Find some other models or parameters to tune our current models with and run the experiments again. Use the function `fit_sklearn_models_with_cv()` created above, or you can write your own if you want.
#
# Did you manage to beat the previous approaches?

# %%
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Lasso
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.neural_network import MLPRegressor

# Define new models with different parameters
new_models = [
    ("Support Vector Regressor", SVR(C=1.0, kernel="rbf")),
    ("AdaBoost Regressor", AdaBoostRegressor(n_estimators=50, random_state=42)),
    ("Lasso Regression", Lasso(alpha=0.1)),
    ("Extra Trees Regressor", ExtraTreesRegressor(n_estimators=100, random_state=42)),
    ("MLP Regressor", MLPRegressor(hidden_layer_sizes=(100,), max_iter=500, random_state=42)),
]

# Run the experiments
fit_sklearn_models_with_cv(new_models, X_train, X_test, y_train, y_test)
# Out:
# Support Vector Regressor:
#   RMSE: 77482.01
#   MAE: 54914.40
#   R^2: -0.051
#   CV R^2 (mean ± std): -0.129 ± 0.135
# 🏃 View run Support Vector Regressor at: http://localhost:5000/#/experiments/2/runs/74e1775c9ba94fc081f2cd0cca4af5f8
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
#
# AdaBoost Regressor:
#   RMSE: 32431.57
#   MAE: 23248.62
#   R^2: 0.816
#   CV R^2 (mean ± std): 0.794 ± 0.078
# 🏃 View run AdaBoost Regressor at: http://localhost:5000/#/experiments/2/runs/e79c8969f883471f83dc6f8def00848f
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
#
# Lasso Regression:
#   RMSE: 24077.53
#   MAE: 16759.25
#   R^2: 0.899
#   CV R^2 (mean ± std): 0.857 ± 0.054
# 🏃 View run Lasso Regression at: http://localhost:5000/#/experiments/2/runs/0122e75d8347488cba86cbabcd462a9b
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
#
# Extra Trees Regressor:
#   RMSE: 23448.54
#   MAE: 14918.67
#   R^2: 0.904
#   CV R^2 (mean ± std): 0.873 ± 0.044
# 🏃 View run Extra Trees Regressor at: http://localhost:5000/#/experiments/2/runs/5350cf31adcb49f3881562591bad05a1
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
#
# MLP Regressor:
#   RMSE: 150973.78
#   MAE: 132830.13
#   R^2: -2.989
#   CV R^2 (mean ± std): -4.115 ± 0.864
# 🏃 View run MLP Regressor at: http://localhost:5000/#/experiments/2/runs/2223538af0dd40d38610e3f53cff13eb
# 🧪 View experiment at: http://localhost:5000/#/experiments/2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3. Manual logging with PyTorch

# %% [markdown]
# In this section, we'll implement manual logging for PyTorch models. While scikit-learn has autologging, PyTorch requires manual tracking - giving us full control over what and when to log. MLflow supports autologging for [PyTorch Lightning](https://lightning.ai/docs/pytorch/stable/), but many people prefer or often need low-level control of pure PyTorch. Thus, we will focus on this approach, which also will teach us more about powerful MLflow capabilities.
#
# Note that we need to turn off scikit-learn autologging! Since we are using a Jupyter Notebook, MLflow uses the previously configured autologging unless explicitly turned off.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import KFold

# disable sklearn autologging!
mlflow.sklearn.autolog(disable=True)

mlflow.set_experiment("pytorch-housing-manual")
# Out:
# 2025/06/07 14:09:11 INFO mlflow.tracking.fluent: Experiment with name 'pytorch-housing-manual' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/home/pawel/sandbox/studia_ai/id/lab06/mlflow-artifacts/2', creation_time=1749298151758, experiment_id='2', last_update_time=1749298151758, lifecycle_stage='active', name='pytorch-housing-manual', tags={}>

# %% [markdown]
# ### 3.1 Targets transformation

# %% [markdown]
# Before training the neural network, we will transform the training target, in order to stabilize the training. To see why, let's plot the house prices:

# %%
y_train.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Training on such targets is possible, but very large target values easily risk overflow, particularly when a loss function like mean squared error is used. We will use the log-transform to transform this distribution, as it's near-exponential, so it should bring it closer to normal, and also greatly reduce the values range.
#
# Of course, we will need to transform the network predictions back again to evaluate them!

# %%
y_train_log = np.log1p(y_train)

pd.Series(y_train_log).plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### 3.2 Define and train the model

# %% [markdown]
# Since we have tabular data, we will use a simple 2-layer multilayer perceptron (MLP).

# %%
class HousePriceNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=128, dropout_rate=0.2):
        super(HousePriceNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# For training, we will check both the 5-fold CV performance, and the traditional train-test split. Cross-validation will give us an additional, robust performance estimation, as well as standard deviation, which is useful for comparing performances of different models. After all, if the difference between models would be within one standard deviation, it wouldn't really be meaningful.

# %%
import torch.nn as nn


class PyTorchTrainer:
    def __init__(
        self, model_class: type[nn.Module], config: dict
    ):
        self.model_class = model_class
        self.config = config

    def create_model(self, input_dim: int) -> nn.Module:
        return self.model_class(
            input_dim=input_dim,
            hidden_dim=self.config["hidden_units"],
            dropout_rate=self.config["dropout"],
        )

    def create_data_loader(
        self, X: torch.Tensor, y: torch.Tensor, shuffle: bool = True
    ) -> DataLoader:
        dataset = TensorDataset(X, y)
        return DataLoader(
            dataset, batch_size=self.config["batch_size"], shuffle=shuffle
        )

    def train_epoch(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        criterion: nn.Module,
        optimizer: optim.Optimizer,
    ) -> float:
        model.train()
        epoch_loss = 0.0
        batch_count = 0

        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            batch_count += 1

        return epoch_loss / batch_count

    def train_model(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        epochs: int,
        metric_prefix: str = "",
    ) -> None:
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=self.config["learning_rate"])

        for epoch in range(epochs):
            avg_mse = self.train_epoch(model, train_loader, criterion, optimizer)

            if epoch % self.config["log_interval"] == 0:
                metric_name = (
                    f"{metric_prefix}train_mse" if metric_prefix else "train_mse"
                )
                # manually log metric value, with a given name and step value
                mlflow.log_metric(metric_name, avg_mse, step=epoch)

    @torch.no_grad()
    def evaluate_model(
        self,
        model: nn.Module,
        X: torch.Tensor,
        y_test: torch.Tensor,
        log_prefix: str = "",
    ) -> dict[str, float]:
        model.eval()
        
        y_pred_norm = model(X)

        # revert the logarithm with exponent
        y_pred = np.expm1(y_pred_norm.numpy())
        y_test = y_test.numpy()

        rmse = root_mean_squared_error(y_test.ravel(), y_pred.ravel())
        mae = mean_absolute_error(y_test.ravel(), y_pred.ravel())
        r2 = r2_score(y_test.ravel(), y_pred.ravel())

        if log_prefix:
            # manually log metrics that we want
            mlflow.log_metric(f"{log_prefix}_rmse", rmse)
            mlflow.log_metric(f"{log_prefix}_mae", mae)
            mlflow.log_metric(f"{log_prefix}_r2", r2)

        return {"rmse": rmse, "mae": mae, "r2": r2}

    def run_cross_validation(
        self, X_train: torch.Tensor, y_train: torch.Tensor, n_splits: int = 5
    ) -> tuple[float, float, list[float]]:
        kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
        cv_scores = []

        for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
            print(f"\nTraining Fold {fold + 1}/{n_splits}...")

            X_fold_train = X_train[train_idx]
            y_fold_train = y_train[train_idx]
            X_fold_val = X_train[val_idx]
            y_fold_val = y_train[val_idx]

            fold_model = self.create_model(X_train.shape[1])
            fold_loader = self.create_data_loader(X_fold_train, y_fold_train)

            self.train_model(
                fold_model,
                fold_loader,
                self.config["epochs"],
                metric_prefix=f"fold_{fold + 1}_",
            )

            # transform validation data with exponent back to original unit
            y_fold_val = np.expm1(y_fold_val)
            
            val_metrics = self.evaluate_model(
                fold_model, X_fold_val, y_fold_val, log_prefix=f"fold_{fold + 1}_val"
            )

            cv_scores.append(val_metrics["r2"])
            print(
                f"  Fold {fold + 1} "
                f"Validation - RMSE: {val_metrics['rmse']:.2f}, "
                f"MAE: {val_metrics['mae']:.2f} "
                f"R^2: {val_metrics['r2']:.3f}"
            )

        return np.mean(cv_scores), np.std(cv_scores), cv_scores

    def fit(
        self,
        X_train: pd.DataFrame | np.ndarray,
        y_train: pd.Series | np.ndarray,
        X_test: pd.DataFrame | np.ndarray,
        y_test: pd.Series | np.ndarray,
    ) -> dict:
        X_train, X_test, y_train, y_test = self._prepare_tensors(
            X_train, X_test, y_train, y_test
        )

        with mlflow.start_run(run_name=self.config["name"]):
            mlflow.log_params(self.config)

            print(f"Starting 5-fold cross-validation for {self.config['name']}...")
            cv_mean, cv_std, cv_scores = self.run_cross_validation(X_train, y_train)

            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            print(
                f"\nCross-validation complete. Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})"
            )
            print("\nTraining final model on all training data...")

            final_model = self.create_model(X_train.shape[1])
            final_loader = self.create_data_loader(X_train, y_train)

            self.train_model(
                final_model,
                final_loader,
                self.config["epochs"],
                metric_prefix="final_model_",
            )

            print("\nEvaluating on test set...")
            test_metrics = self.evaluate_model(final_model, X_test, y_test)

            mlflow.log_metric("test_rmse", test_metrics["rmse"])
            mlflow.log_metric("test_mae", test_metrics["mae"])
            mlflow.log_metric("test_r2", test_metrics["r2"])

            self._print_results(test_metrics, cv_mean, cv_std)

            return {
                "rmse": test_metrics["rmse"],
                "mae": test_metrics["mae"],
                "r2": test_metrics["r2"],
                "cv_r2_mean": cv_mean,
                "cv_r2_std": cv_std,
                "cv_scores": cv_scores,
            }

    def _prepare_tensors(self, X_train, X_test, y_train, y_test) -> tuple:
        y_train = np.array(y_train)
        y_test = np.array(y_test)
        
        X_train_tensor = torch.FloatTensor(X_train)
        y_train_tensor = torch.FloatTensor(y_train.reshape(-1, 1))
        
        X_test_tensor = torch.FloatTensor(X_test)
        y_test_tensor = torch.FloatTensor(y_test.reshape(-1, 1))

        print(f"Training samples: {X_train_tensor.shape[0]}")
        print(f"Input features: {X_train_tensor.shape[1]}")
        
        return X_train_tensor, X_test_tensor, y_train_tensor, y_test_tensor
    
    def _print_results(
        self, test_metrics: dict[str, float], cv_mean: float, cv_std: float
    ) -> None:
        print(f"{'=' * 50}\n")
        print(f"  Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})")
        print("\nCross-Validation Performance:")
        print(f"  R^2: {test_metrics['r2']:.3f}")
        print(f"  RMSE: {test_metrics['rmse']:.2f}")
        print(f"  MAE: {test_metrics['mae']:.2f}")
        print("Test Set Performance:")
        print(f"{'=' * 50}")
        print(f"FINAL RESULTS for {self.config['name']}:")
        print(f"\n{'=' * 50}")

# %% [markdown]
# Quite a bit of code there! So now let's train the model.

# %%
base_config = {
    "model_class": HousePriceNet,
    "random_seed": 42,
    "log_interval": 5,
    "num_samples": X_train.shape[0],
    "input_features": X_train.shape[1],
    "k_folds": 5,
}

config = {
    "name": "first_run",
    "hidden_units": 128,
    "dropout": 0.1,
    "learning_rate": 0.03,
    "epochs": 150,
    "batch_size": 32,
}

# %%
training_config = base_config | config

trainer = PyTorchTrainer(training_config["model_class"], training_config)
results = trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for first_run...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 23415.88, MAE: 17539.84 R^2: 0.911
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 33822.74, MAE: 26574.33 R^2: 0.807
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 46688.75, MAE: 36014.77 R^2: 0.693
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 36534.73, MAE: 27425.32 R^2: 0.779
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 35903.00, MAE: 25946.35 R^2: 0.800
#
# Cross-validation complete. Mean R^2: 0.798 (+/- 0.070)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.798 (+/- 0.070)
#
# Cross-Validation Performance:
#   R^2: 0.880
#   RMSE: 26184.75
#   MAE: 18792.58
# Test Set Performance:
# ==================================================
# FINAL RESULTS for first_run:
#
# ==================================================
# 🏃 View run first_run at: http://localhost:5000/#/experiments/2/runs/86a51760a3d140c3b3f22c2d3bf0efc2
# 🧪 View experiment at: http://localhost:5000/#/experiments/2

# %% [markdown]
# Go to the MLflow dashboard and take a look at logged values. Focus particularly on the "Model metrics" tab, which for neural networks visualizes the progress of iterative training.

# %% [markdown]
# ### 3.3 Hyperparameter optimization with MLflow

# %% [markdown]
# Now, we will use MLflow logging and visualization capabilities to help us tune hyperparameters of neural networks. This is one of the major applications of experiment tracking frameworks. As neural networks have many hyperparameters, with complex interactions, and training them many times is very computationally intensive, we want to use human judgment, based on plots and metrics, to guide our choices in further experiments.
#
# A quick recap on main hyperparameters of MLPs:
#
# 1. **Learning rate:**
#    - typically 1e-5 to 1e-1
#    - too high: loss explodes, model diverges
#    - too low: slow convergence, might get stuck
#    - sweet spot: fast convergence to good minimum
#
# 3. **Model size** - number of hidden units here:
#    - typically 32 to 512
#    - too few: underfitting, can't capture patterns
#    - too many: overfitting, slow training, diminishing returns
#    - consider: more features need more capacity
#
# 5. **Dropout rate:**
#    - typically 0.0 to 0.5
#    - 0.0: no regularization, risk overfitting
#    - too high: underfitting, loses important information
#    - purpose: prevents over-reliance on specific neurons
#
# 7. **Batch size:**
#    - typically 16 to 128
#    - small: noisy gradients, often better generalization, slower
#    - large: stable gradients, faster training, needs more memory, may overfit
#    - trade-off: speed vs generalization
#
# 9. **Number of epochs:**
#    - too few: underfitting
#    - too many: overfitting
#    - optimal: when validation loss stops improving
#    - watch validation loss

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Your task is to:
# 1. Run 10 experiments by modifying the hyperparameter configuration. Try to improve model performance, which is currently overfitted.
# 2. Analyze results in MLflow UI.
# 3. Comment on what changes impacted the model performance the most, and what changes disrupted the training process.
# 4. Compare the results of our first scikit-learn configuration with the first PyTorch experiments. Do you see any overfitting in the first PyTorch experiment? Explain what signs of overfitting can indicate this situation.
#
# Example:
#
# ```python
#
# base_config = {
#     # or any other your own architecture :) we definitely recommend to experiment by yourselves
#     "model_class": HousePriceNet,
#     "random_seed": 42,
#     "log_interval": 5,
#     "input_features": X_train.shape[1],
#     "num_samples": X_train.shape[0],
#     "target_normalized": True,
#     "k_folds": 5,
# }
#
# configs = {
#      {
#         "name": "first_run_or_other_your_own_meaningful_name",
#         "hidden_units": 128,
#          ...
#      },
#     {
#         "name": "second_run_or...",
#         "hidden_units": 128,
#         "dropout": 0.1,
#         "learning_rate": 0.03,
#         "epochs": 150,
#         "batch_size": 32,
#     }
# }
#
# for config in configs:
#     # in python we can in elegant way merge two dicts using "|" operator - finally...
#     # old merging method {**base_config, **config} - ugly :(
#     training_config = base_config | config
#     trainer = PyTorchTrainer(training_config["model_class"], preprocessor, training_config)
#     results = trainer.fit(X_train, y_train, X_test, y_test)
# ```
#
# or just manually and incrementally:
#
# ```python
# new_config = {
#     "name": "second_run_or...",
#     "hidden_units": 128,
#     "dropout": 0.1,
#     "learning_rate": 0.03,
#     "epochs": 150,
#     "batch_size": 32,
# }
#
# training_config = base_config | config
# trainer = PyTorchTrainer(training_config["model_class"], preprocessor, training_config)
# results = trainer.fit(X_train, y_train, X_test, y_test)
# ```

# %% [markdown]
# ### Lab assessment
#
# Fill the code exercises in this Jupyter notebook, and send it with completed exercises, written comments in Markdown cells (particularly for questions in exercise 2), and screenshots of results in MLflow.

# %%
# Define 10 different configurations for hyperparameter tuning
configs = [
    {"name": "run_1", "hidden_units": 64, "dropout": 0.2, "learning_rate": 0.01, "epochs": 100, "batch_size": 16},
    {"name": "run_2", "hidden_units": 128, "dropout": 0.3, "learning_rate": 0.005, "epochs": 150, "batch_size": 32},
    {"name": "run_3", "hidden_units": 256, "dropout": 0.1, "learning_rate": 0.02, "epochs": 200, "batch_size": 64},
    {"name": "run_4", "hidden_units": 128, "dropout": 0.4, "learning_rate": 0.01, "epochs": 120, "batch_size": 32},
    {"name": "run_5", "hidden_units": 64, "dropout": 0.2, "learning_rate": 0.03, "epochs": 100, "batch_size": 16},
    {"name": "run_6", "hidden_units": 256, "dropout": 0.3, "learning_rate": 0.005, "epochs": 150, "batch_size": 64},
    {"name": "run_7", "hidden_units": 128, "dropout": 0.1, "learning_rate": 0.02, "epochs": 200, "batch_size": 32},
    {"name": "run_8", "hidden_units": 64, "dropout": 0.3, "learning_rate": 0.01, "epochs": 150, "batch_size": 16},
    {"name": "run_9", "hidden_units": 256, "dropout": 0.2, "learning_rate": 0.03, "epochs": 120, "batch_size": 64},
    {"name": "run_10", "hidden_units": 128, "dropout": 0.4, "learning_rate": 0.005, "epochs": 100, "batch_size": 32},
]

# Run experiments for each configuration
for config in configs:
    training_config = base_config | config
    trainer = PyTorchTrainer(training_config["model_class"], training_config)
    results = trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for run_1...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 37650.97, MAE: 29816.52 R^2: 0.770
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 29197.51, MAE: 20036.01 R^2: 0.856
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 46035.59, MAE: 34180.86 R^2: 0.701
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 24787.32, MAE: 16136.90 R^2: 0.898
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 44291.68, MAE: 35241.62 R^2: 0.695
#
# Cross-validation complete. Mean R^2: 0.784 (+/- 0.081)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.784 (+/- 0.081)
#
# Cross-Validation Performance:
#   R^2: 0.764
#   RMSE: 36745.84
#   MAE: 27341.57
# Test Set Performance:
# ==================================================
# FINAL RESULTS for run_1:
#
# ==================================================
# 🏃 View run run_1 at: http://localhost:5000/#/experiments/2/runs/907ff58e14454ec39b7b9ef3f9cb79a4
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for run_2...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 64827.59, MAE: 42792.78 R^2: 0.317
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 44261.90, MAE: 31167.18 R^2: 0.669
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 55692.46, MAE: 37954.52 R^2: 0.563
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 58827.80, MAE: 48297.42 R^2: 0.427
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 99473.12, MAE: 80723.57 R^2: -0.538
#
# Cross-validation complete. Mean R^2: 0.288 (+/- 0.430)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.288 (+/- 0.430)
#
# Cross-Validation Performance:
#   R^2: 0.682
#   RMSE: 42649.39
#   MAE: 29632.91
# Test Set Performance:
# ==================================================
# FINAL RESULTS for run_2:
#
# ==================================================
# 🏃 View run run_2 at: http://localhost:5000/#/experiments/2/runs/eb6955a4719d49818b3c3668ac080a23
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for run_3...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 48336.71, MAE: 33800.86 R^2: 0.621
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 57154.51, MAE: 39704.69 R^2: 0.448
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 162746.42, MAE: 128248.93 R^2: -2.736
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 121829.72, MAE: 90971.53 R^2: -1.458
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 48039.70, MAE: 34789.64 R^2: 0.641
#
# Cross-validation complete. Mean R^2: -0.497 (+/- 1.369)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: -0.497 (+/- 1.369)
#
# Cross-Validation Performance:
#   R^2: 0.495
#   RMSE: 53709.24
#   MAE: 43649.38
# Test Set Performance:
# ==================================================
# FINAL RESULTS for run_3:
#
# ==================================================
# 🏃 View run run_3 at: http://localhost:5000/#/experiments/2/runs/33667b40cdae4bdfb1e0562a634e404d
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for run_4...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 36633.72, MAE: 28134.01 R^2: 0.782
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 27383.79, MAE: 19823.33 R^2: 0.873
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 26867.59, MAE: 19500.42 R^2: 0.898
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 49339.18, MAE: 40863.12 R^2: 0.597
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 38444.19, MAE: 26626.02 R^2: 0.770
#
# Cross-validation complete. Mean R^2: 0.784 (+/- 0.106)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.784 (+/- 0.106)
#
# Cross-Validation Performance:
#   R^2: 0.886
#   RMSE: 25479.16
#   MAE: 17470.77
# Test Set Performance:
# ==================================================
# FINAL RESULTS for run_4:
#
# ==================================================
# 🏃 View run run_4 at: http://localhost:5000/#/experiments/2/runs/2c7c06e45af24b77a199e1a81cffef5a
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for run_5...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 27966.29, MAE: 18705.36 R^2: 0.873
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 25352.88, MAE: 17536.72 R^2: 0.891
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 23676.65, MAE: 16822.64 R^2: 0.921
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 30021.83, MAE: 20883.48 R^2: 0.851
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 34653.60, MAE: 24066.21 R^2: 0.813
#
# Cross-validation complete. Mean R^2: 0.870 (+/- 0.036)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.870 (+/- 0.036)
#
# Cross-Validation Performance:
#   R^2: 0.809
#   RMSE: 32999.64
#   MAE: 23799.75
# Test Set Performance:
# ==================================================
# FINAL RESULTS for run_5:
#
# ==================================================
# 🏃 View run run_5 at: http://localhost:5000/#/experiments/2/runs/03643dab5dd14a40b997fd7ac12cacc6
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for run_6...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 72629.44, MAE: 52177.57 R^2: 0.143
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 99133.30, MAE: 68696.19 R^2: -0.662
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 69778.06, MAE: 50820.25 R^2: 0.313
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 129768.14, MAE: 95171.39 R^2: -1.789
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 49595.43, MAE: 39182.17 R^2: 0.618
#
# Cross-validation complete. Mean R^2: -0.275 (+/- 0.867)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: -0.275 (+/- 0.867)
#
# Cross-Validation Performance:
#   R^2: 0.444
#   RMSE: 56386.96
#   MAE: 39563.41
# Test Set Performance:
# ==================================================
# FINAL RESULTS for run_6:
#
# ==================================================
# 🏃 View run run_6 at: http://localhost:5000/#/experiments/2/runs/43cd398da9044f2ebb3026ca79ed9665
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for run_7...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 30910.51, MAE: 22191.14 R^2: 0.845
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 27643.55, MAE: 19310.54 R^2: 0.871
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 47202.14, MAE: 36178.30 R^2: 0.686
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 88007.19, MAE: 68466.66 R^2: -0.283
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 36700.37, MAE: 27444.24 R^2: 0.791
#
# Cross-validation complete. Mean R^2: 0.582 (+/- 0.437)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.582 (+/- 0.437)
#
# Cross-Validation Performance:
#   R^2: 0.871
#   RMSE: 27100.59
#   MAE: 19170.69
# Test Set Performance:
# ==================================================
# FINAL RESULTS for run_7:
#
# ==================================================
# 🏃 View run run_7 at: http://localhost:5000/#/experiments/2/runs/234456efc3de43dea9d4c4373d4c77fd
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for run_8...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 35248.86, MAE: 24517.65 R^2: 0.798
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 27183.35, MAE: 20115.52 R^2: 0.875
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 27096.02, MAE: 18775.10 R^2: 0.896
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 27466.71, MAE: 17654.11 R^2: 0.875
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 30994.79, MAE: 21491.14 R^2: 0.851
#
# Cross-validation complete. Mean R^2: 0.859 (+/- 0.034)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.859 (+/- 0.034)
#
# Cross-Validation Performance:
#   R^2: 0.887
#   RMSE: 25427.61
#   MAE: 17803.31
# Test Set Performance:
# ==================================================
# FINAL RESULTS for run_8:
#
# ==================================================
# 🏃 View run run_8 at: http://localhost:5000/#/experiments/2/runs/70d12731c58f40a0a4243575cb5eaf91
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for run_9...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 246525.55, MAE: 182667.02 R^2: -8.870
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 73548.41, MAE: 54582.80 R^2: 0.085
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 61139.37, MAE: 45043.05 R^2: 0.473
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 43640.26, MAE: 31530.42 R^2: 0.685
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 109647.93, MAE: 97649.17 R^2: -0.869
#
# Cross-validation complete. Mean R^2: -1.699 (+/- 3.625)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: -1.699 (+/- 3.625)
#
# Cross-Validation Performance:
#   R^2: 0.237
#   RMSE: 66022.53
#   MAE: 40699.08
# Test Set Performance:
# ==================================================
# FINAL RESULTS for run_9:
#
# ==================================================
# 🏃 View run run_9 at: http://localhost:5000/#/experiments/2/runs/d8d15761b1d24fceb09ef992bf5aab36
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for run_10...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 87489.87, MAE: 37172.70 R^2: -0.243
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 52348.27, MAE: 40417.48 R^2: 0.537
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 61155.11, MAE: 45778.80 R^2: 0.472
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 47287.09, MAE: 36041.71 R^2: 0.630
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 61876.34, MAE: 51359.49 R^2: 0.405
#
# Cross-validation complete. Mean R^2: 0.360 (+/- 0.311)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.360 (+/- 0.311)
#
# Cross-Validation Performance:
#   R^2: 0.689
#   RMSE: 42123.04
#   MAE: 32095.64
# Test Set Performance:
# ==================================================
# FINAL RESULTS for run_10:
#
# ==================================================
# 🏃 View run run_10 at: http://localhost:5000/#/experiments/2/runs/34b7427c6ca04b57aaf828624163bee3
# 🧪 View experiment at: http://localhost:5000/#/experiments/2

# %% [markdown]
# ### Analysis of Model Performance and Overfitting
#
# #### Impact of Hyperparameter Changes on Model Performance
# - **Learning Rate**: Lower rates improved generalization but were slower. Higher rates were faster but unstable.
# - **Hidden Units**: More units captured patterns better but risked overfitting. Fewer units underfit.
# - **Dropout**: Moderate dropout reduced overfitting. High dropout caused underfitting.
# - **Batch Size**: Small batches improved generalization but were slower. Large batches were faster but risked overfitting.
# - **Epochs**: Too many caused overfitting. Too few led to underfitting.
#
# #### Comparison of scikit-learn and PyTorch
# - **scikit-learn**: Models like Random Forest had good performance and generalization.
# - **PyTorch**: Overfitted with high training scores but lower validation and test scores.
#
# #### Signs of Overfitting in PyTorch
# - Training loss was much lower than validation loss.
# - Test metrics were worse than training metrics.
# - Cross-validation scores had high variance.
#
# To fix overfitting, try more dropout, fewer hidden units, or early stopping.
